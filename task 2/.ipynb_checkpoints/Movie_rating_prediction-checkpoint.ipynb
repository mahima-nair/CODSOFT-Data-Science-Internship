# %% [markdown]
# Task 2: Movie Rating Prediction

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('IMDb_Movies_India.csv')

# %%
df.isnull().sum()
# Out:
# Name           0
# Year         528
# Duration    8269
# Genre       1877
# Rating      7590
# Votes       7589
# Director     525
# Actor 1     1617
# Actor 2     2384
# Actor 3     3144
# dtype: int64

# %%
df.shape
# Out:
# (15509, 10)

# %%
df.head()
# Out:
#                                  Name    Year Duration            Genre  \
# 0                                         NaN      NaN            Drama
# 1  #Gadhvi (He thought he was Gandhi) -2019.0  109 min            Drama
# 2                         #Homecoming -2021.0   90 min   Drama, Musical
# 3                             #Yaaram -2019.0  110 min  Comedy, Romance
# 4                   ...And Once Again -2010.0  105 min            Drama
#
#    Rating Votes            Director       Actor 1             Actor 2  \
# 0     NaN   NaN       J.S. Randhawa      Manmauji              Birbal
# 1     7.0     8       Gaurav Bakshi  Rasika Dugal      Vivek Ghamande
# 2     NaN   NaN  Soumyajit Majumdar  Sayani Gupta   Plabita Borthakur
# 3     4.4    35          Ovais Khan       Prateik          Ishita Raj
# 4     NaN   NaN        Amol Palekar  Rajat Kapoor  Rituparna Sengupta
#
#            Actor 3
# 0  Rajendra Bhatia
# 1    Arvind Jangid
# 2       Roy Angana
# 3  Siddhant Kapoor
# 4      Antara Mali

# %%
df.head(50)
# Out:
#                                   Name    Year Duration  \
# 0                                          NaN      NaN
# 1   #Gadhvi (He thought he was Gandhi) -2019.0  109 min
# 2                          #Homecoming -2021.0   90 min
# 3                              #Yaaram -2019.0  110 min
# 4                    ...And Once Again -2010.0  105 min
# 5                 ...Aur Pyaar Ho Gaya -1997.0  147 min
# 6                            ...Yahaan -2005.0  142 min
# 7                       .in for Motion -2008.0   59 min
# 8                   ?: A Question Mark -2012.0   82 min
# 9                             @Andheri -2014.0  116 min
# 10           1:1.6 An Ode to Lost Love -2004.0   96 min
# 11                1:13:7 Ek Tera Saath -2016.0  120 min
# 12                            100 Days -1991.0  161 min
# 13                           100% Love -2012.0  166 min
# 14                          101 Ratein -1990.0      NaN
# 15                         102 Not Out -2018.0  102 min
# 16                         108 Limited     NaN      NaN
# 17                     108 Teerthyatra -1987.0      NaN
# 18                           10ml LOVE -2010.0   87 min
# 19                          11 O'Clock -1948.0      NaN
# 20                          12 Bulbule -2021.0      NaN
# 21                          12 O'Clock -1958.0  132 min
# 22                          12 O'Clock -2021.0  105 min
# 23                            12 Years     NaN      NaN
# 24                                124a -2021.0      NaN
# 25                               127 B -2017.0  116 min
# 26                13 May Gulaabi Nagar -2010.0      NaN
# 27                  13 Tribute of Love -2020.0   66 min
# 28         13B: Fear Has a New Address -2009.0  146 min
# 29                            14 Phere -2021.0      NaN
# 30                      15 Park Avenue -2005.0  116 min
# 31                     150 Seconds Ago -2002.0  112 min
# 32                         15th August -1993.0  168 min
# 33                              16-Dec -2002.0  158 min
# 34                               18.11 -2014.0  126 min
# 35                                1857 -1946.0      NaN
# 36                      19 Revolutions -2004.0   94 min
# 37                                1911     NaN      NaN
# 38                                1920 -2008.0  138 min
# 39                         1920 London -2016.0  120 min
# 40                  1920: Evil Returns -2012.0  124 min
# 41                                1921 -2018.0  144 min
# 42                  1942: A Love Story -1994.0  157 min
# 43                                1971 -2007.0  136 min
# 44              1978: A Teen Night Out -2019.0  107 min
# 45              1982 - A Love Marriage -2017.0  113 min
# 46                        19th January -2014.0      NaN
# 47                        2 Band Radio -2019.0      NaN
# 48                        2 GB Ki Life     NaN      NaN
# 49                    2 Little Indians -2013.0      NaN
#
#                         Genre  Rating  Votes                 Director  \
# 0                       Drama     NaN    NaN            J.S. Randhawa
# 1                       Drama     7.0      8            Gaurav Bakshi
# 2              Drama, Musical     NaN    NaN       Soumyajit Majumdar
# 3             Comedy, Romance     4.4     35               Ovais Khan
# 4                       Drama     NaN    NaN             Amol Palekar
# 5      Comedy, Drama, Musical     4.7    827             Rahul Rawail
# 6         Drama, Romance, War     7.4  1,086           Shoojit Sircar
# 7                 Documentary     NaN    NaN            Anirban Datta
# 8   Horror, Mystery, Thriller     5.6    326            Allyson Patel
# 9     Action, Crime, Thriller     4.0     11        Biju Bhaskar Nair
# 10                      Drama     6.2     17              Madhu Ambat
# 11                     Horror     5.9     59          Arshad Siddiqui
# 12  Horror, Romance, Thriller     6.5    983             Partho Ghosh
# 13     Comedy, Drama, Romance     5.7    512              Rabi Kinagi
# 14                   Thriller     NaN    NaN                   Harish
# 15              Comedy, Drama     7.4  6,619             Umesh Shukla
# 16                        NaN     NaN    NaN              Anand Anddy
# 17     Comedy, Drama, Fantasy     NaN    NaN                  Rajpati
# 18     Comedy, Drama, Romance     6.3    162          Sharat Katariya
# 19                        NaN     NaN    NaN               Homi Wadia
# 20      Comedy, Drama, Family     NaN    NaN               Jagat Joon
# 21      Crime, Drama, Mystery     7.2     72       Pramod Chakravorty
# 22           Horror, Thriller     4.4     63          Ram Gopal Varma
# 23                  Biography     NaN    NaN            Sohail Tatari
# 24                Documentary     NaN    NaN           Varrun Sukhraj
# 25             Comedy, Horror     6.6     26                Seshu Kmr
# 26                     Action     NaN    NaN              N.K. Pareek
# 27                      Drama     NaN    NaN             Rahul Tiwari
# 28     Drama, Horror, Mystery     7.3  6,329          Vikram K. Kumar
# 29                     Comedy     NaN    NaN           Devanshu Singh
# 30                      Drama     7.1  1,002               Aparna Sen
# 31                        NaN     NaN    NaN           Batul Mukhtiar
# 32                      Drama     5.6     15            Vicky Ranawat
# 33           Action, Thriller     6.9  1,235             Mani Shankar
# 34                     Action     3.5     10            Mohibul Haque
# 35             Drama, History     5.0      8              Mohan Sinha
# 36                      Drama     4.5     16            Sridhar Reddy
# 37      Drama, History, Sport     NaN    NaN           Nikkhil Advani
# 38   Horror, Mystery, Romance     6.4  3,100             Vikram Bhatt
# 39            Horror, Mystery     4.1  1,559  Dharmendra Suresh Desai
# 40     Drama, Horror, Romance     4.8  1,811            Bhushan Patel
# 41   Horror, Mystery, Romance     4.5  1,069             Vikram Bhatt
# 42     Action, Drama, History     7.2  3,223       Vidhu Vinod Chopra
# 43         Action, Drama, War     8.1  1,892              Amrit Sagar
# 44                   Thriller     4.0     20                 Aziz Zee
# 45                     Comedy     5.5    106            Prashant Gore
# 46                      Drama     7.3     16              Sanjay Amar
# 47                     Comedy     NaN    NaN                Saki Shah
# 48                      Drama     NaN    NaN                      NaN
# 49             Comedy, Family     5.6     14              Ravi Bhatia
#
#                   Actor 1                 Actor 2            Actor 3
# 0                Manmauji                  Birbal    Rajendra Bhatia
# 1            Rasika Dugal          Vivek Ghamande      Arvind Jangid
# 2            Sayani Gupta       Plabita Borthakur         Roy Angana
# 3                 Prateik              Ishita Raj    Siddhant Kapoor
# 4            Rajat Kapoor      Rituparna Sengupta        Antara Mali
# 5              Bobby Deol  Aishwarya Rai Bachchan      Shammi Kapoor
# 6         Jimmy Sheirgill          Minissha Lamba     Yashpal Sharma
# 7                     NaN                     NaN                NaN
# 8               Yash Dave          Muntazir Ahmad       Kiran Bhatia
# 9               Augustine            Fathima Babu               Byon
# 10         Rati Agnihotri          Gulshan Grover      Atul Kulkarni
# 11           Pankaj Berry            Anubhav Dhir       Hritu Dudani
# 12          Jackie Shroff           Madhuri Dixit      Javed Jaffrey
# 13                   Jeet           Koyel Mallick        Sujoy Ghosh
# 14              Saraswati            Disco Shanti                NaN
# 15       Amitabh Bachchan            Rishi Kapoor         Vijay Raaz
# 16             Vijay Raaz           Sanjay Mishra       Brahmanandam
# 17           Pravin Anand             Nayan Bhatt              Jeetu
# 18         Neil Bhoopalam             Anusha Bose  Manu Rishi Chadha
# 19                  Aftab            Sayani Atish  Austin Ki Bachchi
# 20            Sonu Sonkar           Sunita Verman      Anubhav Dixit
# 21              Guru Dutt          Waheeda Rehman         Shashikala
# 22     Mithun Chakraborty       Makrand Deshpande        Dalip Tahil
# 23                    NaN                     NaN                NaN
# 24                    NaN                     NaN                NaN
# 25               Mast Ali              Aziz Naser        Heena Shaik
# 26          Nirmal Pandey          Khushi Rajpoot    Raj Singh Verma
# 27  Rahul Tiwari Adhiyari              Anil Arora        Asima Bhatt
# 28               Madhavan           Neetu Chandra     Poonam Dhillon
# 29         Vikrant Massey         Kriti Kharbanda       Gauahar Khan
# 30           Shabana Azmi      Konkona Sen Sharma         Rahul Bose
# 31                    NaN                     NaN                NaN
# 32              Ronit Roy            Tisca Chopra      Shakti Kapoor
# 33           Milind Soman         Danny Denzongpa     Gulshan Grover
# 34             Rehal Khan          Gulshan Grover      Mukesh Tiwari
# 35          Nigar Sultana                 Suraiya        Menaka Devi
# 36            Tarun Arora          Gulshan Grover       Vinay Pandey
# 37           John Abraham                     NaN                NaN
# 38       Rajniesh Duggall             Adah Sharma       Anjori Alagh
# 39          Sharman Joshi            Meera Chopra      Vishal Karwal
# 40            Vicky Ahuja              Tia Bajpai   Tarakesh Chauhan
# 41            Zareen Khan            Karan Kundra       Vikram Bhatt
# 42            Anil Kapoor           Jackie Shroff    Manisha Koirala
# 43         Manoj Bajpayee             Ravi Kishan    Deepak Dobriyal
# 44          Abuzar Akhtar          Apurva Godbole    Vaishnavi Kadam
# 45       Amitkumar Sharma                    Omna       Rita Agarwal
# 46           Mumtaz Ahmed              Bidita Bag     Madhuri Bhatia
# 47    Bilal Ahamad Bhagat             Neelu Dogra        Rahat Kazmi
# 48                    NaN                     NaN                NaN
# 49            Ravi Bhatia            Ronak Bhatia       Kamal Chopra

# %%
df2=df.copy()

# %%
df2.head()
# Out:
#                                  Name    Year Duration            Genre  \
# 0                                         NaN      NaN            Drama
# 1  #Gadhvi (He thought he was Gandhi) -2019.0  109 min            Drama
# 2                         #Homecoming -2021.0   90 min   Drama, Musical
# 3                             #Yaaram -2019.0  110 min  Comedy, Romance
# 4                   ...And Once Again -2010.0  105 min            Drama
#
#    Rating Votes            Director       Actor 1             Actor 2  \
# 0     NaN   NaN       J.S. Randhawa      Manmauji              Birbal
# 1     7.0     8       Gaurav Bakshi  Rasika Dugal      Vivek Ghamande
# 2     NaN   NaN  Soumyajit Majumdar  Sayani Gupta   Plabita Borthakur
# 3     4.4    35          Ovais Khan       Prateik          Ishita Raj
# 4     NaN   NaN        Amol Palekar  Rajat Kapoor  Rituparna Sengupta
#
#            Actor 3
# 0  Rajendra Bhatia
# 1    Arvind Jangid
# 2       Roy Angana
# 3  Siddhant Kapoor
# 4      Antara Mali

# %%
df2.shape
# Out:
# (15509, 10)

# %%
#df2['Genre'].dropna()

# %%
new_genre = df2["Genre"].str.split(",", n=1, expand=True)

# %%
df2['Duration'] = pd.to_numeric(df2['Duration'].str.replace('[^\d]', '', regex=True))

# %%
df2.isnull().sum()
# Out:
# Name           0
# Year         528
# Duration    8269
# Genre       1877
# Rating      7590
# Votes       7589
# Director     525
# Actor 1     1617
# Actor 2     2384
# Actor 3     3144
# dtype: int64

# %%
df3=df2.copy()

# %%
df3["Genre1"] = new_genre[0]
df3["Genre2"] = new_genre[1]
df3 = df3.drop("Genre",axis=1)
df3.head()
# Out:
#                                  Name    Year  Duration  Rating Votes  \
# 0                                         NaN       NaN     NaN   NaN
# 1  #Gadhvi (He thought he was Gandhi) -2019.0     109.0     7.0     8
# 2                         #Homecoming -2021.0      90.0     NaN   NaN
# 3                             #Yaaram -2019.0     110.0     4.4    35
# 4                   ...And Once Again -2010.0     105.0     NaN   NaN
#
#              Director       Actor 1             Actor 2          Actor 3  \
# 0       J.S. Randhawa      Manmauji              Birbal  Rajendra Bhatia
# 1       Gaurav Bakshi  Rasika Dugal      Vivek Ghamande    Arvind Jangid
# 2  Soumyajit Majumdar  Sayani Gupta   Plabita Borthakur       Roy Angana
# 3          Ovais Khan       Prateik          Ishita Raj  Siddhant Kapoor
# 4        Amol Palekar  Rajat Kapoor  Rituparna Sengupta      Antara Mali
#
#    Genre1    Genre2
# 0   Drama      None
# 1   Drama      None
# 2   Drama   Musical
# 3  Comedy   Romance
# 4   Drama      None

# %%
df3['Duration'] = df3['Duration'].fillna(df3['Duration'].median())

# %%
df3.isnull().sum()
# Out:
# Name           0
# Year         528
# Duration       0
# Rating      7590
# Votes       7589
# Director     525
# Actor 1     1617
# Actor 2     2384
# Actor 3     3144
# Genre1      1877
# Genre2      9308
# dtype: int64

# %%
#Dropping the columns having more than 5000 missing values(genre2, Actor3)
df4 = df3.drop(columns=['Genre2','Actor 3', 'Year'], axis=1)

# %%
df4.head()
# Out:
#                                  Name  Duration  Rating Votes  \
# 0                                         131.0     NaN   NaN
# 1  #Gadhvi (He thought he was Gandhi)     109.0     7.0     8
# 2                         #Homecoming      90.0     NaN   NaN
# 3                             #Yaaram     110.0     4.4    35
# 4                   ...And Once Again     105.0     NaN   NaN
#
#              Director       Actor 1             Actor 2  Genre1
# 0       J.S. Randhawa      Manmauji              Birbal   Drama
# 1       Gaurav Bakshi  Rasika Dugal      Vivek Ghamande   Drama
# 2  Soumyajit Majumdar  Sayani Gupta   Plabita Borthakur   Drama
# 3          Ovais Khan       Prateik          Ishita Raj  Comedy
# 4        Amol Palekar  Rajat Kapoor  Rituparna Sengupta   Drama

# %%
df4.isnull().sum()
# Out:
# Name           0
# Duration       0
# Rating      7590
# Votes       7589
# Director     525
# Actor 1     1617
# Actor 2     2384
# Genre1      1877
# dtype: int64

# %%
df5 = df4.dropna(subset=['Rating'])

# %%
df5.head()
# Out:
#                                  Name  Duration  Rating  Votes  \
# 1  #Gadhvi (He thought he was Gandhi)     109.0     7.0      8
# 3                             #Yaaram     110.0     4.4     35
# 5                ...Aur Pyaar Ho Gaya     147.0     4.7    827
# 6                           ...Yahaan     142.0     7.4  1,086
# 8                  ?: A Question Mark      82.0     5.6    326
#
#          Director          Actor 1                 Actor 2  Genre1
# 1   Gaurav Bakshi     Rasika Dugal          Vivek Ghamande   Drama
# 3      Ovais Khan          Prateik              Ishita Raj  Comedy
# 5    Rahul Rawail       Bobby Deol  Aishwarya Rai Bachchan  Comedy
# 6  Shoojit Sircar  Jimmy Sheirgill          Minissha Lamba   Drama
# 8   Allyson Patel        Yash Dave          Muntazir Ahmad  Horror

# %%
df5.isnull().sum()
# Out:
# Name          0
# Duration      0
# Rating        0
# Votes         0
# Director      5
# Actor 1     125
# Actor 2     200
# Genre1      102
# dtype: int64

# %%
df6=df5.dropna()

# %%
df6.isnull().sum()
# Out:
# Name        0
# Duration    0
# Rating      0
# Votes       0
# Director    0
# Actor 1     0
# Actor 2     0
# Genre1      0
# dtype: int64

# %%
df6.shape
# Out:
# (7641, 8)

# %%
df6['Votes'] = df6['Votes'].str.replace(',', '').astype(int)
# Out:
# C:\Users\Mahima Nair\AppData\Local\Temp\ipykernel_1088\3863123988.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df6['Votes'] = df6['Votes'].str.replace(',', '').astype(int)

# %%
df6['Votes'].dtype
# Out:
# dtype('int32')

# %%
df6.head()
# Out:
#                                  Name  Duration  Rating  Votes  \
# 1  #Gadhvi (He thought he was Gandhi)     109.0     7.0      8
# 3                             #Yaaram     110.0     4.4     35
# 5                ...Aur Pyaar Ho Gaya     147.0     4.7    827
# 6                           ...Yahaan     142.0     7.4   1086
# 8                  ?: A Question Mark      82.0     5.6    326
#
#          Director          Actor 1                 Actor 2  Genre1
# 1   Gaurav Bakshi     Rasika Dugal          Vivek Ghamande   Drama
# 3      Ovais Khan          Prateik              Ishita Raj  Comedy
# 5    Rahul Rawail       Bobby Deol  Aishwarya Rai Bachchan  Comedy
# 6  Shoojit Sircar  Jimmy Sheirgill          Minissha Lamba   Drama
# 8   Allyson Patel        Yash Dave          Muntazir Ahmad  Horror

# %%
df6['Votes'].describe()
# Out:
# count      7641.000000
# mean       2007.769402
# std       11805.825912
# min           5.000000
# 25%          17.000000
# 50%          59.000000
# 75%         447.000000
# max      591417.000000
# Name: Votes, dtype: float64

# %%
df7 = df6[df6['Votes'] >= 20]

# %%
df7.head()
# Out:
#                     Name  Duration  Rating  Votes         Director  \
# 3                #Yaaram     110.0     4.4     35       Ovais Khan
# 5   ...Aur Pyaar Ho Gaya     147.0     4.7    827     Rahul Rawail
# 6              ...Yahaan     142.0     7.4   1086   Shoojit Sircar
# 8     ?: A Question Mark      82.0     5.6    326    Allyson Patel
# 11  1:13:7 Ek Tera Saath     120.0     5.9     59  Arshad Siddiqui
#
#             Actor 1                 Actor 2  Genre1
# 3           Prateik              Ishita Raj  Comedy
# 5        Bobby Deol  Aishwarya Rai Bachchan  Comedy
# 6   Jimmy Sheirgill          Minissha Lamba   Drama
# 8         Yash Dave          Muntazir Ahmad  Horror
# 11     Pankaj Berry            Anubhav Dhir  Horror

# %%
df7.shape
# Out:
# (5539, 8)

# %%
df7['Director'].nunique()
# Out:
# 2177

# %%
df7['Actor 1'].nunique()
# Out:
# 1718

# %%
df7['Genre1'].nunique()
# Out:
# 20

# %% [markdown]
# #df9 = df6
# actor1_ratings = df9.groupby('Actor 1')['Rating'].mean()
# actor2_ratings = df9.groupby('Actor 2')['Rating'].mean()
# director_ratings = df9.groupby('Director')['Rating'].mean()

# %% [markdown]
# mapping_dict_actor1 = actor1_ratings.to_dict()
# mapping_dict_actor2 = actor2_ratings.to_dict()
# mapping_dict_director = director_ratings.to_dict()

# %% [markdown]
# dfa1=pd.DataFrame(list(mapping_dict_actor1.items()),columns=['Actor 1', 'Rating'])
# dfa2=pd.DataFrame(list(mapping_dict_actor2.items()),columns=['Actor 2', 'Rating'])
# dfa3=pd.DataFrame(list(mapping_dict_director.items()),columns=['Director', 'Rating'])

# %% [markdown]
# dfa1.head()

# %% [markdown]
# average_ratings = df6.groupby('Actor 1')['Rating'].mean()

# %% [markdown]
# average_ratings

# %% [markdown]
# average_ratings.isnull().sum()

# %% [markdown]
# mapping_dict = average_ratings.to_dict()

# %% [markdown]
# mapping_dict

# %% [markdown]
# dft=pd.DataFrame(list(mapping_dict.items()),columns=['Actor 1', 'Rate'])

# %% [markdown]
# dft.head()

# %% [markdown]
#  dft.to_csv("Ratings.csv", index=False)

# %% [markdown]
# df7=df6

# %% [markdown]
# df4.isnull().sum()

# %% [markdown]
# df7['name_avg_rating'] = df7['Actor 1'].map(mapping_dict)

# %%
df7.head()
# Out:
#                     Name  Duration  Rating  Votes         Director  \
# 3                #Yaaram     110.0     4.4     35       Ovais Khan
# 5   ...Aur Pyaar Ho Gaya     147.0     4.7    827     Rahul Rawail
# 6              ...Yahaan     142.0     7.4   1086   Shoojit Sircar
# 8     ?: A Question Mark      82.0     5.6    326    Allyson Patel
# 11  1:13:7 Ek Tera Saath     120.0     5.9     59  Arshad Siddiqui
#
#             Actor 1                 Actor 2  Genre1
# 3           Prateik              Ishita Raj  Comedy
# 5        Bobby Deol  Aishwarya Rai Bachchan  Comedy
# 6   Jimmy Sheirgill          Minissha Lamba   Drama
# 8         Yash Dave          Muntazir Ahmad  Horror
# 11     Pankaj Berry            Anubhav Dhir  Horror

# %%
df7.shape
# Out:
# (5539, 8)

# %%
def merge_dicts(dict1, dict2):
    merged_dict = {}
    
    # Get all keys from both dictionaries
    all_keys = set(dict1.keys()).union(set(dict2.keys()))
    
    for key in all_keys:
        if key in dict1 and key in dict2:
            # If key is in both dictionaries, compute the mean
            merged_dict[key] = (dict1[key] + dict2[key]) / 2
        elif key in dict1:
            # If key is only in dict1
            merged_dict[key] = dict1[key]
        else:
            # If key is only in dict2
            merged_dict[key] = dict2[key]
    
    return merged_dict

# %%
def df_name_to_rating(df):
    actor1_ratings = df.groupby('Actor 1')['Rating'].mean()
    actor2_ratings = df.groupby('Actor 2')['Rating'].mean()
    director_ratings = df.groupby('Director')['Rating'].mean()
    
    mapping_dict_actor1 = actor1_ratings.to_dict()
    mapping_dict_actor2 = actor2_ratings.to_dict()
    merged_actor_dict = merge_dicts(mapping_dict_actor1,mapping_dict_actor2)
    mapping_dict_director = director_ratings.to_dict()
    
    df_at=pd.DataFrame(list(merged_actor_dict.items()),columns=['Actor', 'Rating_Actor'])
    #dfa2=pd.DataFrame(list(mapping_dict_actor2.items()),columns=['Actor 2', 'Rating_Actor2'])
    df_dr=pd.DataFrame(list(mapping_dict_director.items()),columns=['Director', 'Rating_Director'])

    #merged_actor_df = pd.merge(dfa1, dfa2, left_on='Actor 1', right_on='Actor 2', how='outer')
   

    #df_final = pd.concat([dfa1, dfa2, dfa3], sort=False)
    
    # Save DataFrame to CSV
    df_at.to_csv("Actor_Ratings.csv", index=False)
    df_dr.to_csv("Director.csv", index=False)
    
    df['Actor 1'] = df['Actor 1'].map(mapping_dict_actor1)
    df['Actor 2'] = df['Actor 2'].map(mapping_dict_actor2)
    df['Director'] = df['Director'].map(mapping_dict_director)
    
    return df

# %%
df8=df7.copy()

# %%
df8 = df_name_to_rating(df8)

# %%
df8.head()
# Out:
#                     Name  Duration  Rating  Votes  Director   Actor 1  \
# 3                #Yaaram     110.0     4.4     35  4.400000  5.420000
# 5   ...Aur Pyaar Ho Gaya     147.0     4.7    827  5.358824  4.788889
# 6              ...Yahaan     142.0     7.4   1086  7.500000  5.300000
# 8     ?: A Question Mark      82.0     5.6    326  5.600000  5.600000
# 11  1:13:7 Ek Tera Saath     120.0     5.9     59  6.950000  6.050000
#
#      Actor 2  Genre1
# 3   4.400000  Comedy
# 5   5.786667  Comedy
# 6   6.050000   Drama
# 8   6.320000  Horror
# 11  5.900000  Horror

# %%
df8.shape
# Out:
# (5539, 8)

# %%
# Convert dictionary to DataFrame
#df = pd.DataFrame(data)

# Specify the CSV file path
#csv_file = 'data.csv'

#df = pd.read_csv('data.csv')

# Find the rating of 'abc'
#rating_of_abc = df[df['name'] == 'abc']['Rating'].values[0]

# %%
df_actor_rating= pd.read_csv("Actor_Ratings.csv")
df_actor_rating.head()
# Out:
#                 Actor  Rating_Actor
# 0  Prashant Narayanan      4.787500
# 1         Babu Antony      5.100000
# 2        Rishi Kapoor      6.072555
# 3     Sheikh Fattelal      7.300000
# 4     Pankaj Tripathi      6.050000

# %%
df_actor_rating.shape
# Out:
# (3119, 2)

# %%
df_dr_rating= pd.read_csv("Director.csv")
df_dr_rating.head()
# Out:
#                Director  Rating_Director
# 0          A. Bhimsingh         6.780000
# 1        A. Jagannathan         5.833333
# 2  A. Kodandarami Reddy         7.200000
# 3              A. Majid         5.700000
# 4              A. Muthu         3.000000

# %%
df9 = df8.drop(columns=["Votes","Name"], axis=1)
df9.head()
# Out:
#     Duration  Rating  Director   Actor 1   Actor 2  Genre1
# 3      110.0     4.4  4.400000  5.420000  4.400000  Comedy
# 5      147.0     4.7  5.358824  4.788889  5.786667  Comedy
# 6      142.0     7.4  7.500000  5.300000  6.050000   Drama
# 8       82.0     5.6  5.600000  5.600000  6.320000  Horror
# 11     120.0     5.9  6.950000  6.050000  5.900000  Horror

# %%
#use get_dummies function of pandas to perform one hot encoding(changing categorical to binary attributes)
dummies = pd.get_dummies(df9.Genre1)
dummies.head()
# Out:
#     Action  Adventure  Animation  Biography  Comedy  Crime  Documentary  \
# 3    False      False      False      False    True  False        False
# 5    False      False      False      False    True  False        False
# 6    False      False      False      False   False  False        False
# 8    False      False      False      False   False  False        False
# 11   False      False      False      False   False  False        False
#
#     Drama  Family  Fantasy  History  Horror  Music  Musical  Mystery  Romance  \
# 3   False   False    False    False   False  False    False    False    False
# 5   False   False    False    False   False  False    False    False    False
# 6    True   False    False    False   False  False    False    False    False
# 8   False   False    False    False    True  False    False    False    False
# 11  False   False    False    False    True  False    False    False    False
#
#     Sci-Fi  Sport  Thriller    War
# 3    False  False     False  False
# 5    False  False     False  False
# 6    False  False     False  False
# 8    False  False     False  False
# 11   False  False     False  False

# %%
#def input_name_to_rating(name):

genre_stats = df8.groupby('Genre1')['Genre1'].agg('count').sort_values(ascending=False)
genre_stats
# Out:
# Genre1
# Action         1717
# Drama          1713
# Comedy         1011
# Crime           266
# Romance         159
# Horror          112
# Musical          89
# Adventure        83
# Biography        77
# Thriller         77
# Mystery          56
# Family           52
# Documentary      48
# Animation        38
# Fantasy          23
# Sci-Fi            5
# History           5
# Music             3
# War               3
# Sport             2
# Name: Genre1, dtype: int64

# %%
df10 = pd.concat([df9,dummies.drop('War',axis='columns')], axis='columns') #to avoid a dummy variable trap in one hot encoding, we can drop one column and to represent the value of 1st column use 00000...00
df10.head()
# Out:
#     Duration  Rating  Director   Actor 1   Actor 2  Genre1  Action  Adventure  \
# 3      110.0     4.4  4.400000  5.420000  4.400000  Comedy   False      False
# 5      147.0     4.7  5.358824  4.788889  5.786667  Comedy   False      False
# 6      142.0     7.4  7.500000  5.300000  6.050000   Drama   False      False
# 8       82.0     5.6  5.600000  5.600000  6.320000  Horror   False      False
# 11     120.0     5.9  6.950000  6.050000  5.900000  Horror   False      False
#
#     Animation  Biography  ...  Fantasy  History  Horror  Music  Musical  \
# 3       False      False  ...    False    False   False  False    False
# 5       False      False  ...    False    False   False  False    False
# 6       False      False  ...    False    False   False  False    False
# 8       False      False  ...    False    False    True  False    False
# 11      False      False  ...    False    False    True  False    False
#
#     Mystery  Romance  Sci-Fi  Sport  Thriller
# 3     False    False   False  False     False
# 5     False    False   False  False     False
# 6     False    False   False  False     False
# 8     False    False   False  False     False
# 11    False    False   False  False     False
#
# [5 rows x 25 columns]

# %%
df10 = df10.drop("Genre1", axis=1)

# %%
df10.head()
# Out:
#     Duration  Rating  Director   Actor 1   Actor 2  Action  Adventure  \
# 3      110.0     4.4  4.400000  5.420000  4.400000   False      False
# 5      147.0     4.7  5.358824  4.788889  5.786667   False      False
# 6      142.0     7.4  7.500000  5.300000  6.050000   False      False
# 8       82.0     5.6  5.600000  5.600000  6.320000   False      False
# 11     120.0     5.9  6.950000  6.050000  5.900000   False      False
#
#     Animation  Biography  Comedy  ...  Fantasy  History  Horror  Music  \
# 3       False      False    True  ...    False    False   False  False
# 5       False      False    True  ...    False    False   False  False
# 6       False      False   False  ...    False    False   False  False
# 8       False      False   False  ...    False    False    True  False
# 11      False      False   False  ...    False    False    True  False
#
#     Musical  Mystery  Romance  Sci-Fi  Sport  Thriller
# 3     False    False    False   False  False     False
# 5     False    False    False   False  False     False
# 6     False    False    False   False  False     False
# 8     False    False    False   False  False     False
# 11    False    False    False   False  False     False
#
# [5 rows x 24 columns]

# %% [markdown]
# ### Machine Learning model built

# %%
X = df10.drop(columns=["Rating"], axis=1)
X.head()
# Out:
#     Duration  Director   Actor 1   Actor 2  Action  Adventure  Animation  \
# 3      110.0  4.400000  5.420000  4.400000   False      False      False
# 5      147.0  5.358824  4.788889  5.786667   False      False      False
# 6      142.0  7.500000  5.300000  6.050000   False      False      False
# 8       82.0  5.600000  5.600000  6.320000   False      False      False
# 11     120.0  6.950000  6.050000  5.900000   False      False      False
#
#     Biography  Comedy  Crime  ...  Fantasy  History  Horror  Music  Musical  \
# 3       False    True  False  ...    False    False   False  False    False
# 5       False    True  False  ...    False    False   False  False    False
# 6       False   False  False  ...    False    False   False  False    False
# 8       False   False  False  ...    False    False    True  False    False
# 11      False   False  False  ...    False    False    True  False    False
#
#     Mystery  Romance  Sci-Fi  Sport  Thriller
# 3     False    False   False  False     False
# 5     False    False   False  False     False
# 6     False    False   False  False     False
# 8     False    False   False  False     False
# 11    False    False   False  False     False
#
# [5 rows x 23 columns]

# %%
Y = df10["Rating"]
Y.head()
# Out:
# 3     4.4
# 5     4.7
# 6     7.4
# 8     5.6
# 11    5.9
# Name: Rating, dtype: float64

# %%
#Train test splitting
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.2, random_state=10)

# %%
#To improve the accuracy by k folds cross validation of dataset to find optimal mix of data that provides max information and makes a good model
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score

cv = ShuffleSplit(n_splits=5,test_size=0.2, random_state=0)

cross_val_score(LinearRegression(), X, Y, cv=cv)
# Out:
# array([0.74312025, 0.74602477, 0.7459238 , 0.72426313, 0.73489812])

# %%
#To try different regressor models and find out which one gives the best score
#Use Grid Search CV for this method

from sklearn.model_selection import GridSearchCV

from sklearn.linear_model import Lasso
from sklearn.tree import DecisionTreeRegressor

def find_best_model_using_gridSearchCV(X,y):
    #python dictionary of algos to compare
    algos = {
        'linear_regression': {
            'model': LinearRegression(),
            'params': {
                #'normalize':[True, False]
            }
        },
        'lasso' :{
            'model':Lasso(),
            'params':{
                'alpha':[1,2],
                'selection':['random','cyclic']
            }
        },
        'decision_tree': {
            'model': DecisionTreeRegressor(),
            'params':{
                'criterion': ['squared_error','friedman_mse'],
                'splitter':['best', 'random']
            }
        }
    }
    
#The gridSearch method will not only search the best model, but will also find the best hyperparameters for the model. This is known as Hyperparameter Tuning
    scores = []
    cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)
    for algo_name, config in algos.items():
        gs = GridSearchCV(config['model'], config['params'], cv=cv, return_train_score=False)
        gs.fit(X,y)
        scores.append({
            'model':algo_name,
            'best_score':gs.best_score_,
            'best_params':gs.best_params_
        })
        #Training each of the model and finding the score might take time

        #return the score of each of the model for us to evaluate the best one
    return pd.DataFrame(scores, columns=['model','best_score','best_params'])

# %%
find_best_model_using_gridSearchCV(X,Y)
# Out:
#                model  best_score  \
# 0  linear_regression    0.738846
# 1              lasso    0.189081
# 2      decision_tree    0.502049
#
#                                          best_params
# 0                                                 {}
# 1                {'alpha': 1, 'selection': 'cyclic'}
# 2  {'criterion': 'friedman_mse', 'splitter': 'best'}

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression

# Number of subsets
num_subsets = 10

# To store the results
predictions = []
actuals = []
errors = []

# Train-test splits and model training
for _ in range(num_subsets):
    X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)
    model = LinearRegression()
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    
    predictions.append(y_pred)
    actuals.append(y_test)
    errors.append(y_test - y_pred)

# Convert lists to arrays for easier manipulation
predictions = np.array(predictions)
actuals = np.array(actuals)
errors = np.array(errors)

# Calculate the mean prediction for each data point
mean_predictions = np.mean(predictions, axis=0)

# Bias calculation: mean error
bias = np.mean(errors)

# Variance calculation: average of the squared differences between each prediction and the mean prediction
variance = np.mean((predictions - mean_predictions) ** 2)

print(f'Bias: {bias}')
print(f'Variance: {variance}')
# Out:
# Bias: -0.007139622690085557
# Variance: 1.234529084432444

# %%
from sklearn.linear_model import LinearRegression
linearModel = LinearRegression()
linearModel.fit(X_train, y_train)
linearModel.score(X_test, y_test)
# Out:
# 0.7354593230839024

# %%
X_train.columns
# Out:
# Index(['Duration', 'Director', 'Actor 1', 'Actor 2', 'Action', 'Adventure',
#        'Animation', 'Biography', 'Comedy', 'Crime', 'Documentary', 'Drama',
#        'Family', 'Fantasy', 'History', 'Horror', 'Music', 'Musical', 'Mystery',
#        'Romance', 'Sci-Fi', 'Sport', 'Thriller'],
#       dtype='object')

# %%
#both linear and lasso is giving a good result compared to decision tree
#Choosing Linear(85.7%) score 
#linear is already trained in cell 71

def predict_rate(duration,director,actor1,actor2,genre):
    genre_index = np.where(X.columns==genre)[0][0]  #find location index and set that particular index value in predict array to 1 thereby converting it to binary for simpler model built
    x = np.zeros(len(X.columns))
    x[0] = duration
    x[1] = df_dr_rating[df_dr_rating['Director'] == director]['Rating_Director'].values[0]
    x[2] = df_actor_rating[df_actor_rating['Actor'] == actor1]['Rating_Actor'].values[0]
    x[3] = df_actor_rating[df_actor_rating['Actor'] == actor2]['Rating_Actor'].values[0]

    
    if genre_index >0:
        x[genre_index] = 1
    return linearModel.predict([x])[0]

# %%
df_actor_rating.head(100)
# Out:
#                  Actor  Rating_Actor
# 0   Prashant Narayanan      4.787500
# 1          Babu Antony      5.100000
# 2         Rishi Kapoor      6.072555
# 3      Sheikh Fattelal      7.300000
# 4      Pankaj Tripathi      6.050000
# ..                 ...           ...
# 95         Vijay Anand      6.491667
# 96        Allan Border      3.800000
# 97        Pankaj Berry      6.425000
# 98            Aga Jaan      7.600000
# 99            Lalu Ram      8.000000
#
# [100 rows x 2 columns]

# %%
predict_rate(109,"Abrar Alvi","Rishi Kapoor","Pankaj Tripathi","Action")
# Out:
# C:\Users\Mahima Nair\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 7.218758786499569

# %%
df11 = df9.drop(columns=["Genre1"], axis=1)
a=(np.var(X,axis=0))
a
# Out:
# Duration       546.727531
# Director         1.198446
# Actor 1          1.024763
# Actor 2          1.081624
# Action           0.213894
# Adventure        0.014760
# Animation        0.006813
# Biography        0.013708
# Comedy           0.149209
# Crime            0.045717
# Documentary      0.008591
# Drama            0.213619
# Family           0.009300
# Fantasy          0.004135
# History          0.000902
# Horror           0.019811
# Music            0.000541
# Musical          0.015810
# Mystery          0.010008
# Romance          0.027882
# Sci-Fi           0.000902
# Sport            0.000361
# Thriller         0.013708
# dtype: float64
